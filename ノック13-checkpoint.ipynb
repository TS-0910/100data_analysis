# %%
import pandas as pd

# %%
uriage_data = pd.read_csv("uriage.csv")
uriage_data.head()
# Out:
#          purchase_date item_name  item_price customer_name
# 0  2019-06-13 18:02:34       商品A       100.0         深井菜々美
# 1  2019-07-13 13:05:29     商 品 S         NaN          浅田賢二
# 2  2019-05-11 19:42:07     商 品 a         NaN          南部慶二
# 3  2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒
# 4  2019-04-22 03:09:35       商品a         NaN          平田鉄二

# %%
kokyaku_data = pd.read_excel("kokyaku_daicho.xlsx")
kokyaku_data.head()
# Out:
#       顧客名        かな  地域                     メールアドレス         登録日
# 0   須賀ひとみ    すが ひとみ  H市     suga_hitomi@example.com  2018/01/04
# 1  岡田　 敏也   おかだ としや  E市   okada_toshiya@example.com       42782
# 2    芳賀 希    はが のぞみ  A市     haga_nozomi@example.com  2018/01/07
# 3   荻野  愛    おぎの あい  F市        ogino_ai@example.com       42872
# 4   栗田 憲一  くりた けんいち  E市  kurita_kenichi@example.com       43127

# %%
uriage_data["item_name"].head()
# Out:
# 0      商品A
# 1    商 品 S
# 2    商 品 a
# 3      商品Z
# 4      商品a
# Name: item_name, dtype: object

# %%
uriage_data["item_price"].head()
# Out:
# 0     100.0
# 1       NaN
# 2       NaN
# 3    2600.0
# 4       NaN
# Name: item_price, dtype: float64

# %%
uriage_data["purchase_date"] = pd.to_datetime(uriage_data["purchase_date"])
uriage_data["purchase_month"] = uriage_data["purchase_date"].dt.strftime("%Y%m")
uriage_data["purchase_month"]
# Out:
# 0       201906
# 1       201907
# 2       201905
# 3       201902
# 4       201904
#          ...
# 2994    201902
# 2995    201906
# 2996    201903
# 2997    201907
# 2998    201907
# Name: purchase_month, Length: 2999, dtype: object

# %%
uriage_data.head()
# Out:
#         purchase_date item_name  item_price customer_name purchase_month
# 0 2019-06-13 18:02:34       商品A       100.0         深井菜々美         201906
# 1 2019-07-13 13:05:29     商 品 S         NaN          浅田賢二         201907
# 2 2019-05-11 19:42:07     商 品 a         NaN          南部慶二         201905
# 3 2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒         201902
# 4 2019-04-22 03:09:35       商品a         NaN          平田鉄二         201904

# %%
uriage_data["item_name2"] =uriage_data["item_name"]
uriage_data
# Out:
#            purchase_date item_name  item_price customer_name purchase_month  \
# 0    2019-06-13 18:02:34       商品A       100.0         深井菜々美         201906
# 1    2019-07-13 13:05:29     商 品 S         NaN          浅田賢二         201907
# 2    2019-05-11 19:42:07     商 品 a         NaN          南部慶二         201905
# 3    2019-02-12 23:40:45       商品Z      2600.0          麻生莉緒         201902
# 4    2019-04-22 03:09:35       商品a         NaN          平田鉄二         201904
# ...                  ...       ...         ...           ...            ...
# 2994 2019-02-15 02:56:39       商品Y      2500.0          福島友也         201902
# 2995 2019-06-22 04:03:43       商品M      1300.0          大倉晃司         201906
# 2996 2019-03-29 11:14:05       商品Q         NaN          尾形小雁         201903
# 2997 2019-07-14 12:56:49       商品H         NaN          芦田博之         201907
# 2998 2019-07-21 00:31:36       商品D       400.0          石田郁恵         201907
#
#      item_name2
# 0           商品A
# 1         商 品 S
# ...

# %%
uriage_data.pivot_table(index = "purchase_month", columns = "item_name", values = "item_name2", aggfunc = "count")
# Out:
# item_name         商品W   商 品 n   商品E   商品M   商品P   商品S   商品W   商品X  商  品O  \
# purchase_month
# 201901            NaN     1.0   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 201902            NaN     NaN   NaN   NaN   NaN   NaN   NaN   1.0    NaN
# 201903            NaN     NaN   1.0   1.0   1.0   NaN   NaN   NaN    NaN
# 201904            1.0     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 201905            NaN     NaN   NaN   NaN   NaN   1.0   NaN   NaN    NaN
# 201906            NaN     NaN   NaN   NaN   NaN   NaN   1.0   NaN    NaN
# 201907            NaN     NaN   NaN   NaN   NaN   NaN   NaN   NaN    1.0
#
# item_name       商  品Q  ...  商品k  商品l  商品o  商品p  商品r  商品s  商品t  商品v  商品x  商品y
# purchase_month         ...
# 201901            NaN  ...  1.0  1.0  1.0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 201902            NaN  ...  NaN  NaN  NaN  NaN  NaN  1.0  1.0  1.0  NaN  NaN
# 201903            NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
uriage_data.pivot_table(index = "purchase_month", columns = "item_name", values = "item_price", aggfunc = "sum")
# Out:
# item_name          商品W   商 品 n    商品E     商品M     商品P     商品S     商品W     商品X  \
# purchase_month
# 201901             NaN  1400.0    NaN     NaN     NaN     NaN     NaN     NaN
# 201902             NaN     NaN    NaN     NaN     NaN     NaN     NaN  2400.0
# 201903             NaN     NaN  500.0  1300.0  1600.0     NaN     NaN     NaN
# 201904          2300.0     NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 201905             NaN     NaN    NaN     NaN     NaN  1900.0     NaN     NaN
# 201906             NaN     NaN    NaN     NaN     NaN     NaN  2300.0     NaN
# 201907             NaN     NaN    NaN     NaN     NaN     NaN     NaN     NaN
#
# item_name       商  品O   商  品Q  ...     商品k     商品l     商品o     商品p     商品r  \
# purchase_month                 ...
# 201901            NaN     NaN  ...  1100.0  1200.0  1500.0     NaN     NaN
# 201902            NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN
# ...
