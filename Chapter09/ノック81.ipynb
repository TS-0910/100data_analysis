# %% [markdown]
# # ノック81 - 画像データを読み込む(自身の解答)

# %%
from IPython.display import Image
import cv2

# %%
# 画像の表示

Image('img01.jpg')

# %%
# 画像の大きさの表示

img01 = cv2.imread('img01.jpg')

w,h,c = img01.shape
print("画像の幅 :"  + str(w))
print("画像の高さ :"  + str(h))
# Out:
# 画像の幅 :1440
# 画像の高さ :1920
